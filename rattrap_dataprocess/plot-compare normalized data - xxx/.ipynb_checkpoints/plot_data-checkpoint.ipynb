# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import subprocess
import pandas as pd
import shutil
import scipy.optimize as op
# %matplotlib notebook

# %%
#reads the alldata file (as is from rattrap) and returns a temp list with the data in file 
def read_data_file(filename):
    temp_list = []
    try:
        file = open(filename, "r")
        start_reading = False
        for line in file:
            line = line.split('\t') # tab separated columns
            if start_reading:
                temp_list.append(np.array(line))
            if "Energy_(eV)" in line:
                # keeping track of data versus headers and comments
                Title = line
                Title[-1] = line[-1].format().replace('\n','')
                start_reading = True
    finally:
        file.close()
    return temp_list

# %%
directory = 'data'

# %%
file_list = [f for f in os.listdir(directory) if 'norm' in f]
F = len(file_list)
print(F)
print(file_list)
# Out:
# 28
# ['1m0m115c_norm-old.txt', '1m0m115c_norm.txt', '1m0m135c_norm-old.txt', '1m0m135c_norm.txt', '1m10m115C_norm-old.txt', '1m10m115C_norm.txt', '1m10m135C_norm-old.txt', '1m10m135C_norm.txt', '1m10m25C_norm-old.txt', '1m10m25C_norm.txt', '1m1m115c_norm-old.txt', '1m1m115c_norm.txt', '1m1m135c_norm-old.txt', '1m1m135c_norm.txt', '1m3m115c_norm-old.txt', '1m3m115c_norm.txt', '1m3m135c_norm-old.txt', '1m3m135c_norm.txt', '1m5m115c_norm-old.txt', '1m5m115c_norm.txt', '1m5m135c_norm-old.txt', '1m5m135c_norm.txt', '1mzntfms115c_norm-old.txt', '1mzntfms115c_norm.txt', '1mzntfms135c_norm-old.txt', '1mzntfms135c_norm.txt', '1mzntfms25c_norm-old.txt', '1mzntfms25c_norm.txt']

# %%
# Data will be a 3D list that will be [batch number, row, column]
# where the rows and columns are the same from rat trap all data files
Data = []

# %%
# read in every alldata file in the given directory
for filename in file_list:
    Data.append(np.array(read_data_file(f'{directory}/{filename}')))

# %%
# convert list to array
Data = np.array(Data, dtype=float)
#print(Data)
#plt.plot(Data[0,:,0], Data[0,:,1], label = '1m0m115C')
#plt.plot(Data[1,:,0], Data[1,:,1], label = '1m0m135C')
#plt.plot(Data[2,:,0], Data[2,:,1], label = '1m0m135C-old', marker = '.')
#plt.plot(Data[3,:,0], Data[3,:,1], label = '1m0m135C')
plt.plot(Data[5,:,0], Data[5,:,1], label = '1m10m115C', marker = '.')
plt.plot(Data[7,:,0], Data[7,:,1], label = '1m10m135C', marker = '.')
#plt.plot(Data[6,:,0], Data[6,:,1], label = '1m3m135C')
#plt.plot(Data[7,:,0], Data[7,:,1], label = '1m5m115C')
#plt.plot(Data[8,:,0], Data[8,:,1], label = '1m5m135C')
#plt.plot(Data[22,:,0], Data[22,:,1], label = '1mzntfms115C-old')
#plt.plot(Data[23,:,0], Data[23,:,1], label = '1mzntfms115C', marker = '.')
#plt.plot(Data[10,:,0], Data[10,:,1], label = '0.2m Zn(NO3)2')
#plt.plot(Data[11,:,0], Data[11,:,1], label = '1m10m-bulk25C')


plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
