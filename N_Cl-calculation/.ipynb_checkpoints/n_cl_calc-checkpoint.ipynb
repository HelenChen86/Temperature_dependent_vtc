# %%
import numpy as np
import helper as hp

# %%
#ai = range of fractional contribution of corresponding intermediate specie on the total spectra (ideally around 0.25, 0.5, 0.75)
a1 = np.linspace(0.40, 0.50, 6)
a2 = np.linspace(0.64, 0.74, 6)
a3 = np.linspace(0.79, 0.89, 6)
a1 = a1.tolist()
a2 = a2.tolist()
a3 = a3.tolist()

#xi = fraction of corresponding intermediate specie present in the total spectra
x1 = np.linspace(0, 1, 21)
x2 = np.linspace(0, 1, 21)
x3 = np.linspace(0, 1, 21)

coeff_a = hp.set_gen(a1, a2, a3)
coeff_x = hp.set_gen(x1, x2, x3)
print(len(coeff_a))
print(len(coeff_x))
print(a1)
print(x1)
# Out:
# 216
# 9261
# [0.4, 0.42000000000000004, 0.44, 0.46, 0.48, 0.5]
# [0.   0.05 0.1  0.15 0.2  0.25 0.3  0.35 0.4  0.45 0.5  0.55 0.6  0.65
#  0.7  0.75 0.8  0.85 0.9  0.95 1.  ]

# %%
# fraction of tetrahedral from one param fit
frac_apparent = [0.8916, 0.8932]

# %%
out_data = []
for i in frac_apparent:
    out_data.append(hp.final(i, coeff_a, coeff_x))
    
#print(out_data)  
#write to file
hp.write_to_file(out_data, 'outputfile2')
#print(out_data[0][1])
